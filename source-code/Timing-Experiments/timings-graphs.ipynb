# %%
import json

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open("timings-dict.json", "r") as timings_file:
    timings_dict = timings_file.read()
alg_to_time_dict = json.loads(timings_dict)

markers = ['s', '^', '*']
colours = ['blue', 'orange', 'green']

# %%
graph1 = plt.figure()
plt.xlabel("Number of opponents" )
plt.ylabel("Execution time (seconds)")
plt.title("A plot to illustrate the time taken for the computer to execute the tournaments")
for (algorithm, time), marker, colour in zip(alg_to_time_dict.items(), markers, colours):
    plt.plot(log(time), marker=marker, color=colour, label=algorithm)
    plt.yscale("log")    
plt.legend(title='Algorithm Used to Calculate Nash Equilibria')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dba0a3bb23fa> in <module>
#       4 plt.title("A plot to illustrate the time taken for the computer to execute the tournaments")
#       5 for (algorithm, time), marker, colour in zip(alg_to_time_dict.items(), markers, colours):
# ----> 6     plt.plot(log(time), marker=marker, color=colour, label=algorithm)
#       7     plt.yscale("log")
#       8 plt.legend(title='Algorithm Used to Calculate Nash Equilibria')
#
# NameError: name 'log' is not defined
